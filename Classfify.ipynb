# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
batsman_stat = pd.read_csv('batsmanT20.csv')
batsman_stat
# Out:
#             Player Name      Country Time Period  Matches  Played  Not Outs  \
# 0              V Kohli         India   2016-2022       10       9         4
# 1      Mohammad Rizwan      Pakistan   2022-2022        6       6         1
# 2            RG Sharma         India   2016-2022        9       9         0
# 3          Babar Hayat     Hong Kong   2016-2022        5       5         0
# 4       Ibrahim Zadran   Afghanistan   2022-2022        5       5         2
# 5        PBB Rajapaksa     Sri Lanka   2022-2022        6       6         2
# 6        Sabbir Rahman    Bangladesh   2016-2022        6       6         1
# 7       Muhammad Usman           UAE   2016-2016        7       7         1
# 8    Najibullah Zadran   Afghanistan   2016-2022        8       8         3
# 9           P Nissanka     Sri Lanka   2022-2022        6       6         1
# 10         Mahmudullah    Bangladesh   2016-2022        7       7         4
# ...

# %%
batsman_stat.pop('Country')
batsman_stat.pop('Time Period
# Out:
#             Player Name      Country Time Period  Matches  Played  Not Outs  \
# 0              V Kohli         India   2016-2022       10       9         4
# 1      Mohammad Rizwan      Pakistan   2022-2022        6       6         1
# 2            RG Sharma         India   2016-2022        9       9         0
# 3          Babar Hayat     Hong Kong   2016-2022        5       5         0
# 4       Ibrahim Zadran   Afghanistan   2022-2022        5       5         2
# 5        PBB Rajapaksa     Sri Lanka   2022-2022        6       6         2
# 6        Sabbir Rahman    Bangladesh   2016-2022        6       6         1
# 7       Muhammad Usman           UAE   2016-2016        7       7         1
# 8    Najibullah Zadran   Afghanistan   2016-2022        8       8         3
# 9           P Nissanka     Sri Lanka   2022-2022        6       6         1
# 10         Mahmudullah    Bangladesh   2016-2022        7       7         4
# ...
