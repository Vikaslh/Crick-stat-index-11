# %%
# importing necessary libraries.
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot  as plt

# %%
# importing dataset....
keeper_t20 = pd.read_csv('wicketkeeper data t20i.csv')
keeper_t20
# Out:
#             Player Name      Country Time Period  Matches  Played  Dismissals  \
# 0             MS Dhoni         India   2016-2016        5       5           7
# 1             SP Patil           UAE   2016-2016        7       7           7
# 2         LD Chandimal     Sri Lanka   2016-2016        4       3           4
# 3         Sultan Ahmed          Oman   2016-2016        3       3           4
# 4           KD Karthik         India   2022-2022        3       1           3
# 5          Nurul Hasan    Bangladesh   2016-2016        2       2           3
# 6     Mohammad Shahzad   Afghanistan   2016-2016        3       3           3
# 7   Rahmanullah Gurbaz   Afghanistan   2022-2022        5       5           3
# 8           BKG Mendis     Sri Lanka   2022-2022        6       6           3
# 9      Mohammad Rizwan      Pakistan   2022-2022        6       6           3
# 10      Sarfaraz Ahmed      Pakistan   2016-2016        4       4           2
# 11     Mushfiqur Rahim    Bangladesh   2016-2022        7       5           2
# 12        SS McKechnie     Hong Kong   2022-2022        2       2           1
# 13         N Dickwella     Sri Lanka   2016-2016        1       1           0
# 14            C Carter     Hong Kong   2016-2016        3       3           0
# 15             RR Pant         India   2022-2022        4       4           0
#
#     Catches  Stumpings  Maximum Dismissals
# 0         6          1                   3
# 1         6          1                   2
# 2         4          0                   2
# 3         2          2                   3
# 4         3          0                   3
# 5         0          3                   2
# 6         1          2                   2
# 7         3          0                   2
# 8         3          0                   2
# 9         3          0                   1
# 10        2          0                   2
# 11        1          1                   1
# 12        1          0                   1
# 13        0          0                   0
# 14        0          0                   0
# 15        0          0                   0

# %%
features = ['Player Name', 'Catches','Stumpings','Maximum Dismissals']
keeper_t20 = keeper_t20.dropna(subset=features) # remove rows not dont have numerical value from the features.
keeper_t20 = keeper_t20[features].copy()
keeper_t20
# Out:
#             Player Name  Catches  Stumpings  Maximum Dismissals
# 0             MS Dhoni         6          1                   3
# 1             SP Patil         6          1                   2
# 2         LD Chandimal         4          0                   2
# 3         Sultan Ahmed         2          2                   3
# 4           KD Karthik         3          0                   3
# 5          Nurul Hasan         0          3                   2
# 6     Mohammad Shahzad         1          2                   2
# 7   Rahmanullah Gurbaz         3          0                   2
# 8           BKG Mendis         3          0                   2
# 9      Mohammad Rizwan         3          0                   1
# 10      Sarfaraz Ahmed         2          0                   2
# 11     Mushfiqur Rahim         1          1                   1
# 12        SS McKechnie         1          0                   1
# 13         N Dickwella         0          0                   0
# 14            C Carter         0          0                   0
# 15             RR Pant         0          0                   0

# %%
# scaling the data.
scaler = StandardScaler()
features = ['Catches','Stumpings','Maximum Dismissals']
scaled_data = pd.DataFrame( scaler.fit_transform(keeper_t20[features]) , columns = features )
scaled_data
# Out:
#      Catches  Stumpings  Maximum Dismissals
# 0   1.994913   0.404520            1.385870
# 1   1.994913   0.404520            0.377964
# 2   0.948401  -0.674200            0.377964
# 3  -0.098110   1.483240            1.385870
# 4   0.425145  -0.674200            1.385870
# 5  -1.144622   2.561959            0.377964
# 6  -0.621366   1.483240            0.377964
# 7   0.425145  -0.674200            0.377964
# 8   0.425145  -0.674200            0.377964
# 9   0.425145  -0.674200           -0.629941
# 10 -0.098110  -0.674200            0.377964
# 11 -0.621366   0.404520           -0.629941
# 12 -0.621366  -0.674200           -0.629941
# 13 -1.144622  -0.674200           -1.637846
# 14 -1.144622  -0.674200           -1.637846
# 15 -1.144622  -0.674200           -1.637846

# %%
''' To find how many clusers are to be formed '''
def elbow_plot( min_k, max_k, k_max_iter):
    sum_squared_distances = []
    k_range = range(min_k,max_k+1)
    for k in k_range:
        km = KMeans(n_clusters=k, max_iter=k_max_iter, n_init=10)
        km.fit(scaled_data)
        sum_squared_distances.append(km.inertia_)
        
    # Plot the score for each value of k
    plt.plot(k_range, sum_squared_distances, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Sum of squared distances')
    plt.title('Elbow Method For Optimal k')
    plt.show()

# %%
# elbow_plot(2,12,15)

# %%
# Clustering the players using k-means algorithm.
km = KMeans(n_clusters=2,n_init=50)
scaled_data['Cluster'] = km.fit_predict(scaled_data) # assigning the cluster number for each datapoint in the dataframe.
scaled_data
# Out:
# C:\Users\Home\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#      Catches  Stumpings  Maximum Dismissals  Cluster
# 0   1.994913   0.404520            1.385870        1
# 1   1.994913   0.404520            0.377964        1
# 2   0.948401  -0.674200            0.377964        1
# 3  -0.098110   1.483240            1.385870        1
# 4   0.425145  -0.674200            1.385870        1
# 5  -1.144622   2.561959            0.377964        1
# 6  -0.621366   1.483240            0.377964        1
# 7   0.425145  -0.674200            0.377964        1
# 8   0.425145  -0.674200            0.377964        1
# 9   0.425145  -0.674200           -0.629941        0
# 10 -0.098110  -0.674200            0.377964        1
# 11 -0.621366   0.404520           -0.629941        0
# 12 -0.621366  -0.674200           -0.629941        0
# 13 -1.144622  -0.674200           -1.637846        0
# 14 -1.144622  -0.674200           -1.637846        0
# 15 -1.144622  -0.674200           -1.637846        0

# %%
scaled_data.insert(0,'Player Name',keeper_t20['Player Name']) # adding player name to the cluster...
scaled_data
# Out:
#             Player Name   Catches  Stumpings  Maximum Dismissals  Cluster
# 0             MS Dhoni   1.994913   0.404520            1.385870        1
# 1             SP Patil   1.994913   0.404520            0.377964        1
# 2         LD Chandimal   0.948401  -0.674200            0.377964        1
# 3         Sultan Ahmed  -0.098110   1.483240            1.385870        1
# 4           KD Karthik   0.425145  -0.674200            1.385870        1
# 5          Nurul Hasan  -1.144622   2.561959            0.377964        1
# 6     Mohammad Shahzad  -0.621366   1.483240            0.377964        1
# 7   Rahmanullah Gurbaz   0.425145  -0.674200            0.377964        1
# 8           BKG Mendis   0.425145  -0.674200            0.377964        1
# 9      Mohammad Rizwan   0.425145  -0.674200           -0.629941        0
# 10      Sarfaraz Ahmed  -0.098110  -0.674200            0.377964        1
# 11     Mushfiqur Rahim  -0.621366   0.404520           -0.629941        0
# 12        SS McKechnie  -0.621366  -0.674200           -0.629941        0
# 13         N Dickwella  -1.144622  -0.674200           -1.637846        0
# 14            C Carter  -1.144622  -0.674200           -1.637846        0
# 15             RR Pant  -1.144622  -0.674200           -1.637846        0

# %%
# spliting the dataframe into diffrent clusters.
b0 = scaled_data.loc[scaled_data['Cluster']==0]
b1 = scaled_data.loc[scaled_data['Cluster']==1]

# %%
len(b0)
# Out:
# 6

# %%
len(b1)
# Out:
# 10
